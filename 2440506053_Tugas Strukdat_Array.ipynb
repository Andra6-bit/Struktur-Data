# %%
#ukuran peta
size = 10
#membuat peta dengan harta karun tersembunyi
treasure_map = ["_" for _ in range(size)]
#Tentukan lokasi harta karun manual
print(f"Selamat datang di Treasure Hunt! peta memiliki {size} lokasi(0 hingga {size-1}).")
treasure_index = int(input(f"Masukkan loasi harta karun(0-{size-1}): "))
while treasure_index < 0 or treasure_index >= size:
  print("Lokasi tidak valid. Masukkan angka dalam rentang yang benar.")
  treasure_index = int(input(f"Masukkan lokasi harta karun(0-{size-1}): "))
treasure_map[treasure_index] = "X" # menyembunyikan harta karun di lokasi yang di pilih

#Fungsi untuk memulai permainan
def play_treasure_hunt():
  print("\nHarta karun telah disembunyikan! sekarang giliran pemain menebak.")
  print("Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.")
  #Loop permainan
  while True:
    #Menampilkan peta tersembunyi kepada pemain
    print("\nPeta saat ini: ", ["_" for _ in range(size)]) #peta tersembunyi
    #input pemain
    try:
      guess = int(input(f"Masukkan tebakanmu (0-{size-1}): "))
    except ValueError:
      print("Masukkan angka yang valid.")
      continue
    #Validasi input
    if guess < 0 or guess >= size:
      print("indeks tidak valid, pilih antara 0 hingga", size-1)
      continue
    #mengecek apakah tebakan benar
    if treasure_map[guess] == "X":
      print("SELAMAT! Kamu menemukan harta karun di lokasi:", guess)
      break
    else:
      print("Tidak ada harta di lokasi ini.Coba Lagi!")
  print("Terimakasih sudah bermain!")
#jalankan permainan
play_treasure_hunt()
# Out:
# Selamat datang di Treasure Hunt! peta memiliki 10 lokasi(0 hingga 9).
# Masukkan loasi harta karun(0-9): 0
#
# Harta karun telah disembunyikan! sekarang giliran pemain menebak.
# Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.
#
# Peta saat ini:  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan tebakanmu (0-9): 0
# SELAMAT! Kamu menemukan harta karun di lokasi: 0
# Terimakasih sudah bermain!

# %%
#ukuran peta berdasarkan inputan user
size = int(input("pemain diminta memasukkan size peta: "))
#membuat peta dengan harta karun tersembunyi
treasure_map = ["_" for _ in range(size)]
#Tentukan lokasi harta karun manual
print(f"Selamat datang di Treasure Hunt! peta memiliki {size} lokasi(0 hingga {size-1}).")
treasure_index = int(input(f"Masukkan loasi harta karun(0-{size-1}): "))
while treasure_index < 0 or treasure_index >= size:
  print("Lokasi tidak valid. Masukkan angka dalam rentang yang benar.")
  treasure_index = int(input(f"Masukkan lokasi harta karun(0-{size-1}): "))
treasure_map[treasure_index] = "X" # menyembunyikan harta karun di lokasi yang di pilih

#Fungsi untuk memulai permainan
def play_treasure_hunt():
  print("\nHarta karun telah disembunyikan! sekarang giliran pemain menebak.")
  print("Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.")
  #Loop permainan
  while True:
    #Menampilkan peta tersembunyi kepada pemain
    print("\nPeta saat ini: ", ["_" for _ in range(size)]) #peta tersembunyi
    #input pemain
    try:
      guess = int(input(f"Masukkan tebakanmu (0-{size-1}): "))
    except ValueError:
      print("Masukkan angka yang valid.")
      continue
    #Validasi input
    if guess < 0 or guess >= size:
      print("indeks tidak valid, pilih antara 0 hingga", size-1)
      continue
    #mengecek apakah tebakan benar
    if treasure_map[guess] == "X":
      print("🎉SELAMAT! Kamu menemukan harta karun di lokasi:", guess)
      break
    else:
      print("Tidak ada harta di lokasi ini.Coba Lagi!")
  print("Terimakasih sudah bermain!")
#jalankan permainan
play_treasure_hunt()
# Out:
# pemain diminta memasukkan size peta: 5
# Selamat datang di Treasure Hunt! peta memiliki 5 lokasi(0 hingga 4).
# Masukkan loasi harta karun(0-4): 10
# Lokasi tidak valid. Masukkan angka dalam rentang yang benar.
# Masukkan lokasi harta karun(0-4): 0
#
# Harta karun telah disembunyikan! sekarang giliran pemain menebak.
# Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.
#
# Peta saat ini:  ['_', '_', '_', '_', '_']
# Masukkan tebakanmu (0-4): 0
# 🎉SELAMAT! Kamu menemukan harta karun di lokasi: 0
# Terimakasih sudah bermain!

# %%
#ukuran peta berdasarkan inputan user
size = int(input("pemain diminta memasukkan size peta: "))
#membuat peta dengan harta karun tersembunyi
treasure_map = ["_" for _ in range(size)]
#Tentukan lokasi harta karun manual
print(f"Selamat datang di Treasure Hunt! peta memiliki {size} lokasi(0 hingga {size-1}).")
#random harta karun
import random
treasure_index = random.randint(0, size-1)
treasure_map[treasure_index] = "X" # menyembunyikan harta karun di lokasi yang di pilih

#Fungsi untuk memulai permainan
def play_treasure_hunt():
  print("\nHarta karun telah disembunyikan! sekarang giliran pemain menebak.")
  print("Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.")
  #Loop permainan
  while True:
    #Menampilkan peta tersembunyi kepada pemain
    print("\nPeta saat ini: ", ["_" for _ in range(size)]) #peta tersembunyi
    #input pemain
    try:
      guess = int(input(f"Masukkan tebakanmu (0-{size-1}): "))
    except ValueError:
      print("Masukkan angka yang valid.")
      continue
    #Validasi input
    if guess < 0 or guess >= size:
      print("indeks tidak valid, pilih antara 0 hingga", size-1)
      continue
    #mengecek apakah tebakan benar
    if treasure_map[guess] == "X":
      print("🎉SELAMAT! Kamu menemukan harta karun di lokasi:", guess)
      break
    else:
      print("❌ Tidak ada harta di lokasi ini.Coba Lagi!")
  print("Terimakasih sudah bermain!")
#jalankan permainan
play_treasure_hunt()
# Out:
# pemain diminta memasukkan size peta: 5
# Selamat datang di Treasure Hunt! peta memiliki 5 lokasi(0 hingga 4).
#
# Harta karun telah disembunyikan! sekarang giliran pemain menebak.
# Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.
#
# Peta saat ini:  ['_', '_', '_', '_', '_']
# Masukkan tebakanmu (0-4): 3
# ❌ Tidak ada harta di lokasi ini.Coba Lagi!
#
# Peta saat ini:  ['_', '_', '_', '_', '_']
# Masukkan tebakanmu (0-4): 2
# 🎉SELAMAT! Kamu menemukan harta karun di lokasi: 2
# Terimakasih sudah bermain!

# %%
#ukuran peta berdasarkan inputan user
size = int(input("pemain diminta memasukkan size peta: "))
#membuat peta dengan harta karun tersembunyi
treasure_map = ["_" for _ in range(size)]
#Tentukan lokasi harta karun manual
print(f"Selamat datang di Treasure Hunt! peta memiliki {size} lokasi(0 hingga {size-1}).")
#random harta karun
import random
treasure_index = random.randint(0, size-1)
treasure_map[treasure_index] = "X" # menyembunyikan harta karun di lokasi yang di pilih

#Fungsi untuk memulai permainan
def play_treasure_hunt():
  print("\nHarta karun telah disembunyikan! sekarang giliran pemain menebak.")
  print("Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.")
  guessed_map = ["_" for _ in range(size)] #peta untuk pemain
  #Loop permainan
  while True:
    #Menampilkan peta tersembunyi kepada pemain
    print("\nPeta saat ini: ", guessed_map) #peta tersembunyi
    #input pemain
    try:
      guess = int(input(f"Masukkan tebakanmu (0-{size-1}): "))
    except ValueError:
      print("Masukkan angka yang valid.")
      continue
    #Validasi input
    if guess < 0 or guess >= size:
      print("indeks tidak valid, pilih antara 0 hingga", size-1)
      continue
    #mengecek apakah tebakan benar
    if treasure_map[guess] == "X":
      print("🎉SELAMAT! Kamu menemukan harta karun di lokasi:", guess)
      break
    else:
      print("❌ Tidak ada harta di lokasi ini.Coba Lagi!")
      guessed_map[guess] = "O" # menandai lokasi yang sudah di pilih
  print("Terimakasih sudah bermain!")
#jalankan permainan
play_treasure_hunt()
# Out:
# pemain diminta memasukkan size peta: 5
# Selamat datang di Treasure Hunt! peta memiliki 5 lokasi(0 hingga 4).
#
# Harta karun telah disembunyikan! sekarang giliran pemain menebak.
# Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.
#
# Peta saat ini:  ['_', '_', '_', '_', '_']
# Masukkan tebakanmu (0-4): 0
# ❌ Tidak ada harta di lokasi ini.Coba Lagi!
#
# Peta saat ini:  ['O', '_', '_', '_', '_']
# Masukkan tebakanmu (0-4): 3
# ❌ Tidak ada harta di lokasi ini.Coba Lagi!
#
# Peta saat ini:  ['O', '_', '_', 'O', '_']
# Masukkan tebakanmu (0-4): 2
# 🎉SELAMAT! Kamu menemukan harta karun di lokasi: 2
# Terimakasih sudah bermain!
