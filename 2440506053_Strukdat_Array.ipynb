# %%
import numpy as np
angka = np.array([1, 2, 3, 4, 5,])
print('Array satu dimensi:', angka)
# Out:
# Array satu dimensi: [1 2 3 4 5]

# %%
matriks = np.array ([[1, 2], [3, 4], [5, 6]])
print('Array dua dimensi:', matriks)
# Out:
# Array dua dimensi: [[1 2]
#  [3 4]
#  [5 6]]

# %%
array3D = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
print('Array tiga dimensi:', array3D)
# Out:
# Array tiga dimensi: [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
#latihan 1
data = [2440506053, 2440506054, 2440506055, 2440506056]
print('data urutan NPM:', data)
print('Elemen Pertama:', data[0])
print('Elemen terakhir:', data[-1])
# Out:
# data urutan NPM: [2440506053, 2440506054, 2440506055, 2440506056]
# Elemen Pertama: 2440506053
# Elemen terakhir: 2440506056

# %%
#Latihan 2
data = [2440506053, 2440506054, 2440506055, 2440506056]
print('data urutan NPM:', data)
data.append(55)
print('data urutan npm setelah penambahan element:', data)
data.pop(0)
print('data urutan npm setelah mengilangkan emelemnt pertama:', data)
# Out:
# data urutan NPM: [2440506053, 2440506054, 2440506055, 2440506056]
# data urutan npm setelah penambahan element: [2440506053, 2440506054, 2440506055, 2440506056, 55]
# data urutan npm setelah mengilangkan emelemnt pertama: [2440506054, 2440506055, 2440506056, 55]

# %%
#latihan 3
fakultas = ['pertanian', 'ekonomi', 'teknik', 'ilmu sosial dan ilmu politik', 'keguruan dan ilmu pendidikan']

for kuliah in fakultas:
  print('fakultas yang ada di untidar:', kuliah)
# Out:
# fakultas yang ada di untidar: pertanian
# fakultas yang ada di untidar: ekonomi
# fakultas yang ada di untidar: teknik
# fakultas yang ada di untidar: ilmu sosial dan ilmu politik
# fakultas yang ada di untidar: keguruan dan ilmu pendidikan

# %%
#latihan 4
data = [5000, 3000, 10000, 15000, 20000]
print('Jumlah total:', sum(data))
print('nilai maksimum:', max(data))
print('nilai minimum:', min(data))
# Out:
# Jumlah total: 53000
# nilai maksimum: 20000
# nilai minimum: 3000

# %%
#latihan 5
matriks = [
    [2, 3, 4, 10],
    [5, 6, 7, 11],
    [7, 12, 14, 13]
]
print('isi array matriks:')
for baris in matriks:
  print(baris)
#latihan 6
print('elemen pada baris 2, kolom 4:', matriks[1][3])
#latihan 7
matriks.append([6, 2, 20, 6])
print('isi array setelah penambahan baris:')
for baris in matriks:
  print(baris)
#latihan 8
matriks[-1].pop(2)
print('array setelah menghapus elemen ke 3 dari baris terakhir:')
for baris in matriks:
  print(baris)
#latihan 9
matriks[-1][-1]=20
print('array setelah mengganti elemen terakhir:')
for baris in matriks:
  print(baris)
# Out:
# isi array matriks:
# [2, 3, 4, 10]
# [5, 6, 7, 11]
# [7, 12, 14, 13]
# elemen pada baris 2, kolom 4: 11
# isi array setelah penambahan baris:
# [2, 3, 4, 10]
# [5, 6, 7, 11]
# [7, 12, 14, 13]
# [6, 2, 20, 6]
# array setelah menghapus elemen ke 3 dari baris terakhir:
# [2, 3, 4, 10]
# [5, 6, 7, 11]
# [7, 12, 14, 13]
# [6, 2, 6]
# array setelah mengganti elemen terakhir:
# [2, 3, 4, 10]
# [5, 6, 7, 11]
# [7, 12, 14, 13]
# [6, 2, 20]

# %%
#latihan 10
belanja = ['Beras', 'gula', 'minyak']
belanja.append('telur')
belanja.append('susu')
belanja.remove('gula')
print('daftar belanjaan terbaru:', belanja)
# Out:
# daftar belanjaan terbaru: ['Beras', 'minyak', 'telur', 'susu']
